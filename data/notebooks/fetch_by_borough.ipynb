# %%
import pandas as pd

df = pd.read_csv(r'/Users/adrianparsons/Documents/programming/empty-lots/web-map/data/vacant_lots_filtered_limit_cols.csv')

df["borough"].value_counts()

"""
BK    2428
QN    2243
BX    1497
SI    1269
MN     510
"""

#b = df[df["borough"] == ""]

grouped = df.groupby("borough")
boroughs = grouped.groups.keys()

for b in boroughs:
    g = grouped.get_group(b)[0:20]
    g.
    #print("group!", b)
